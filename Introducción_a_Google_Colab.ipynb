# %% [markdown]
# <a href="https://colab.research.google.com/github/Zetor27/Primer_repositorio/blob/main/Introducci%C3%B3n_a_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lo Primero que vamos a conocer es la interfaz de Google Colab
#
# este es un ejemplo de una celda de texto. En el cual podemos escribir
# distintos tipos de anotaciones, con el fin de dar una explicación o algún tipo de texto informativo que explique el uso del siguiente código
#
# *La primera parte del código contiene un comentario
# *La segunda parte contiene un printe
# *Por último tenemos la ejecución del programa, lo que normalmente conocemos como el output
#
# ---

# %%
"Esta es una celda de código, aquí colocaremos los diferentes códigos que vamos a ejecutar en Google Colab"
print("Hola grupo de Ciencia de datos 😁")
# Out:
# Hola grupo de Ciencia de datos 😁

# %%
# Código en una celda de Colab
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Gráfico de seno")
plt.show()

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# @title Example form fields
# @markdown Forms support many types of fields.

no_type_checking = ''  # @param
string_type = 'example'  # @param {type: "string"}
slider_value = 142  # @param {type: "slider", min: 100, max: 200}
number = 102  # @param {type: "number"}
date = '2010-11-05'  # @param {type: "date"}
pick_me = "monday"  # @param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" # @param ["apples", "bananas", "oranges"] {allow-input: true}
# @markdown ---

# %%
# !mk dir datos
# Out:
# /bin/bash: line 1: mk: command not found

# %%
# !mkdir datos

# %%
# !ls
# Out:
# datos  sample_data

# %%
# !python --version
# Out:
# Python 3.12.11

# %%
# %%html
# <img width="400px" src="https://static.platzi.com/media/user_upload/portada-33de62d9-0a69-4069-bb92-1c58b00d86a4.jpg"></img>
# Out:
# <img width="400px" src="https://static.platzi.com/media/user_upload/portada-33de62d9-0a69-4069-bb92-1c58b00d86a4.jpg"></img>

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/V7RXyqFUR98?si=aRqyJFnvRvzZpovQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/V7RXyqFUR98?si=aRqyJFnvRvzZpovQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
